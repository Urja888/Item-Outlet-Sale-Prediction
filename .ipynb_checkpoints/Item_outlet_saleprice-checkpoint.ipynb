# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Train.csv")

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.shape
# Out:
# (8523, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df_var = df.select_dtypes("O").keys()
df_var
# Out:
# Index(['Item_Identifier', 'Item_Fat_Content', 'Item_Type', 'Outlet_Identifier',
#        'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type'],
#       dtype='object')

# %%
# df['Item_Weight'].fillna(df['Item_Weight'].mean(),inplace=True)
for var in df_var:
    df[var].fillna(df[var].mode()[0],inplace=True)

# %%
df_int = df.select_dtypes("float64").keys()
df_int
# Out:
# Index(['Item_Weight', 'Item_Visibility', 'Item_MRP', 'Item_Outlet_Sales'], dtype='object')

# %%
for var in df_int:
    df[var].fillna(df[var].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
for var in df_int:
    df[var] = df[var].astype("int64")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                8523 non-null   int64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   int64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   int64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                8523 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   int64
# dtypes: int64(5), object(7)
# memory usage: 799.2+ KB

# %%
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15            9          Low Fat                0
# 1              DRC01            5          Regular                0
# 2              FDN15           17          Low Fat                0
# 3              FDX07           19          Regular                0
# 4              NCD19            8          Low Fat                0
# ...              ...          ...              ...              ...
# 8518           FDF22            6          Low Fat                0
# 8519           FDS36            8          Regular                0
# 8520           NCJ29           10          Low Fat                0
# 8521           FDN46            7          Regular                0
# 8522           DRG01           14          Low Fat                0
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy       249            OUT049
# ...

# %%
df_var
# Out:
# Index(['Item_Identifier', 'Item_Fat_Content', 'Item_Type', 'Outlet_Identifier',
#        'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type'],
#       dtype='object')

# %%
# val1 = df['Item_Identifier'].value_counts().keys()
# for num,var in enumerate(val1):
#     num+=1
#     df['Item_Identifier'].replace(var,num,inplace=True)

# %%
# val2 = df['Item_Fat_Content'].value_counts().keys()
# for num,var in enumerate(val2):
#     num+=1
#     df['Item_Fat_Content'].replace(var,num,inplace=True)

# %%
# val3 = df['Item_Type'].value_counts().keys()
# for num,var in enumerate(val3):
#     num+=1
#     df['Item_Type'].replace(var,num,inplace=True)

# %%
# val4 = df['Outlet_Identifier'].value_counts().keys()
# for num,var in enumerate(val4):
#     num+=1
#     df['Outlet_Identifier'].replace(var,num,inplace=True)

# %%
# val5 = df['Outlet_Size'].value_counts().keys()
# for num,var in enumerate(val5):
#     num+=1
#     df['Outlet_Size'].replace(var,num,inplace=True)

# %%
# val6 = df['Outlet_Location_Type'].value_counts().keys()
# for num,var in enumerate(val6):
#     num+=1
#     df['Outlet_Location_Type'].replace(var,num,inplace=True)

# %%
# val7 = df['Outlet_Type'].value_counts().keys()
# for num,var in enumerate(val7):
#     num+=1
#     df['Outlet_Type'].replace(var,num,inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for x in df:
    if df[x].dtypes == 'object':
        df[x] = le.fit_transform(df[x])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   int32
#  1   Item_Weight                8523 non-null   int64
#  2   Item_Fat_Content           8523 non-null   int32
#  3   Item_Visibility            8523 non-null   int64
#  4   Item_Type                  8523 non-null   int32
#  5   Item_MRP                   8523 non-null   int64
#  6   Outlet_Identifier          8523 non-null   int32
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                8523 non-null   int32
#  9   Outlet_Location_Type       8523 non-null   int32
#  10  Outlet_Type                8523 non-null   int32
#  11  Item_Outlet_Sales          8523 non-null   int64
# dtypes: int32(7), int64(5)
# memory usage: 566.1 KB

# %%
df.head()
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0              156            9                 1                0          4
# 1                8            5                 2                0         14
# 2              662           17                 1                0         10
# 3             1121           19                 2                0          6
# 4             1297            8                 1                0          9
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0       249                  9                       1999            1
# 1        48                  3                       2009            1
# 2       141                  9                       1999            1
# 3       182                  0                       1998            1
# 4        53                  1                       1987            0
#
#    Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales
# ...

# %%
cols = df.drop('Item_Outlet_Sales',axis=1)

# %%
sns.pairplot(df)
plt.show()

# %%
for x in cols:
    sns.lineplot(df[x],df['Item_Outlet_Sales'])
    plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
plt.figure(figsize=(15,10))
sns.histplot(df)
plt.show()
